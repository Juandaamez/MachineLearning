# %% [markdown]
# # Author: Juan David Amezquita Nuñez

# %% [markdown]
# Taller 02 : Pandas

# %%
import pandas as pd

# %%
auth = pd.read_csv("auth.csv")

# %%
auth2 = auth.copy()

# %%
auth2.drop(["pass", "nom_sede", "nom_unidad", "nom_perfil", "codigo", "tip_contrato", "pago"], axis=1)
auth2
# Out:
#            login                              pass           nombres
# 0     1007513618  a23ad92a1e3e9aa520d6aa296d2f9c5c          DANIELA   \
# 1     1003251590  0b8f5e179a4c99d615d932b5c1e3676f    ERIKA NAYARITH
# 2     1001382401  79a9e3166a38c60e48c10a4b772ea053       ANDRÉS JUAN
# 3     1000262460  e1397b76b22debf372bde115adf9214e    YONATAN STIVEN
# 4     1002403748  f7a104a4200f30ff5278c504dc54ec76     STIVEN ANDRES
# ...          ...                               ...               ...
# 2240    59559543  0e6f66ee712b89bd669e3c9cdab219fa  ANDREA DEL PILAR
# 2241    14168016                               NaN         SAMANTHA
# 2242    10794699                               NaN   FRANCISCO FABIO
# 2243    10911959                               NaN          ALFONSO
# 2244    84004240  c4a5ccc158ea29e9cc1858c7a9239b45      EDGAR CAMILO
#
#                apellidos         dni                            correo
# ...

# %%
auth2["password"] = auth2["dni"].apply(lambda x: "Ab." + str(x))
auth2
# Out:
#            login                              pass           nombres
# 0     1007513618  a23ad92a1e3e9aa520d6aa296d2f9c5c          DANIELA   \
# 1     1003251590  0b8f5e179a4c99d615d932b5c1e3676f    ERIKA NAYARITH
# 2     1001382401  79a9e3166a38c60e48c10a4b772ea053       ANDRÉS JUAN
# 3     1000262460  e1397b76b22debf372bde115adf9214e    YONATAN STIVEN
# 4     1002403748  f7a104a4200f30ff5278c504dc54ec76     STIVEN ANDRES
# ...          ...                               ...               ...
# 2240    59559543  0e6f66ee712b89bd669e3c9cdab219fa  ANDREA DEL PILAR
# 2241    14168016                               NaN         SAMANTHA
# 2242    10794699                               NaN   FRANCISCO FABIO
# 2243    10911959                               NaN          ALFONSO
# 2244    84004240  c4a5ccc158ea29e9cc1858c7a9239b45      EDGAR CAMILO
#
#                apellidos         dni                            correo
# ...

# %%
auth2.to_csv("authResult.csv")

# %%
authTest = pd.read_csv("authResult.csv")
authTest
# Out:
#       Unnamed: 0       login                              pass
# 0              0  1007513618  a23ad92a1e3e9aa520d6aa296d2f9c5c  \
# 1              1  1003251590  0b8f5e179a4c99d615d932b5c1e3676f
# 2              2  1001382401  79a9e3166a38c60e48c10a4b772ea053
# 3              3  1000262460  e1397b76b22debf372bde115adf9214e
# 4              4  1002403748  f7a104a4200f30ff5278c504dc54ec76
# ...          ...         ...                               ...
# 2240        2240    59559543  0e6f66ee712b89bd669e3c9cdab219fa
# 2241        2241    14168016                               NaN
# 2242        2242    10794699                               NaN
# 2243        2243    10911959                               NaN
# 2244        2244    84004240  c4a5ccc158ea29e9cc1858c7a9239b45
#
#                nombres           apellidos         dni
# 0             DANIELA        GOMEZ SANCHEZ  1007513618  \
# 1       ERIKA NAYARITH      SAAVEDRA GAMEZ  1003251590
# ...

# %% [markdown]
# # Course

# %%
# Leer archivo csv
df = pd.read_csv("course.csv")
df
# Out:
#                              Column1
# 0                           cod_aula  \
# 1       20232_31009_30611_PRO IXD IV
# 2       20232_32080_99243_ADMI ORGAN
# 3            20232_30002_95085_ARQB5
# 4          20232_30002_95085_AMBIND5
# ...                              ...
# 1313     20232_32090_32109_FRANC 3-A
# 1314  20232_32090_32117_FRAN PREIN-A
# 1315         20232_31005_96181_POO-A
# 1316        20232_31005_37604_ARQEMP
# 1317      20232_31005_41114_REQDIS-A
#
#                                                 Column2
# 0                                              nom_aula  \
# 1                 PROGRAMACION IXD IV_PRO IXD IV(20232)
# 2     ADMINISTRACIÓN DE ORGANISMOS DEPORTIVOS_ADMI O...
# 3                                 INGLES V_ARQB5(20232)
# 4                               INGLES V_AMBIND5(20232)
# ...                                                 ...
# 1313                FRANCÉS BÁSICO III_FRANC 3-A(20232)
# 1314          FRANCÉS PREINTERMEDIO_FRAN PREIN-A(20232)
# ...

# %%
df["Column2"] = df["Column2"].replace("(20232)", "", regex=True)

# %%
df.to_csv("courseResult.csv")

# %%
dfTest = pd.read_csv("courseResult.csv")
dfTest
# Out:
#       Unnamed: 0                         Column1
# 0              0                        cod_aula  \
# 1              1    20232_31009_30611_PRO IXD IV
# 2              2    20232_32080_99243_ADMI ORGAN
# 3              3         20232_30002_95085_ARQB5
# 4              4       20232_30002_95085_AMBIND5
# ...          ...                             ...
# 1313        1313     20232_32090_32109_FRANC 3-A
# 1314        1314  20232_32090_32117_FRAN PREIN-A
# 1315        1315         20232_31005_96181_POO-A
# 1316        1316        20232_31005_37604_ARQEMP
# 1317        1317      20232_31005_41114_REQDIS-A
#
#                                                 Column2
# 0                                              nom_aula  \
# 1                      PROGRAMACION IXD IV_PRO IXD IV()
# 2     ADMINISTRACIÓN DE ORGANISMOS DEPORTIVOS_ADMI O...
# 3                                      INGLES V_ARQB5()
# 4                                    INGLES V_AMBIND5()
# ...
